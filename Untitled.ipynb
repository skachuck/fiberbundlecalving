# %%
# %run ssaErebus.py
# Out:
# CFL cond numb: 0.033293177089
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# Removing particles beyond Lmax
# Calving to Lmax
# ...
